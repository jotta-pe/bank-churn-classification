# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregamento e inspeção inicial dos dados

# %%
# guardando o caminho dos dados
caminho_treino = Path("../data/train.csv")

caminho_teste = Path("../data/test.csv")

# %%
# validando que encontrou o arquivo da base de treino
caminho_treino.exists()
# Out:
# True

# %%
# validando que encontrou o arquivo da base de teste
caminho_teste.exists()
# Out:
# True
